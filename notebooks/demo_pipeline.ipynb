# %% [markdown]
# # Demo Pipeline
# End-to-end demonstration placeholder.

# %%
print('1) Generate monologues -> outputs/monologues')
print('2) TTS to outputs/audio')
print('3) Add noise to outputs/audio_noisy')
print('4) Preprocess audio -> src/resqme/data/processed/audio')
